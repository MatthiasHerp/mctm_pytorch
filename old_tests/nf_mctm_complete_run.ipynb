# %%
import numpy as np
import matplotlib.pyplot as plt

from nf_mctm import *
from training_helpers import *

import torch
from torch.distributions.multivariate_normal import MultivariateNormal

import seaborn as sns
#import statsmodels.api as sm

# %%
loc = torch.zeros(3)
lam = torch.Tensor([[1, 0, 0],
                    [3, 1, 0],
                    [0, 0, 1]])
scale = lam @ torch.eye(3) @ torch.transpose(lam, 0, 1)
y_distribution = MultivariateNormal(loc, scale)
y = y_distribution.sample((2000, 1))  # Generate training data
y = y.reshape((2000, 3))
y.size()

# %%
sns.kdeplot(x=y[:,0], y=y[:,1])
plt.show()
sns.kdeplot(x=y[:,0], y=y[:,2])
plt.show()
sns.kdeplot(x=y[:,1], y=y[:,2])
plt.show()

# %%
import torch
from torch import nn
from flip import Flip
from bernstein_transformation_layer import Transformation
from decorrelation_layer import Decorrelation



class NF_MCTM(nn.Module):
    def __init__(self, polynomial_range, number_variables):
        super(NF_MCTM, self).__init__()
        self.polynomial_range = polynomial_range
        self.number_variables = number_variables

        self.l1 = Transformation(degree=10, number_variables=self.number_variables, polynomial_range=self.polynomial_range.repeat(1,3))
        self.l2 = Decorrelation(degree=12, number_variables=self.number_variables, polynomial_range=self.polynomial_range.repeat(1,3), spline="bernstein")
        #self.l3 = Flip()
        #self.l4 = Decorrelation(degree=12, number_variables=self.number_variables, polynomial_range=self.polynomial_range.repeat(1,3), spline="bernstein")
        #self.l5 = Flip()
        #self.l6 = Decorrelation(degree=12, number_variables=self.number_variables, polynomial_range=self.polynomial_range.repeat(1,3), spline="bernstein")

    def forward(self, x, return_log_d=False):
        if return_log_d==True:
            output, log_d = self.l1(x, return_log_d = True)
            output, log_d = self.l2(output, return_log_d = True)
            #output = self.l3(output)
            #output, log_d = self.l4(output, log_d, return_log_d = True)
            #output = self.l5(output)
            #output, log_d = self.l6(output, log_d, return_log_d=True)

            return output, log_d
        else:
            output = self.l1(x)
            output = self.l2(output)
            #output = self.l3(output)
            #output = self.l4(output)
            #output = self.l5(output)
            #output = self.l6(output)

            return output

# %%
pr = torch.tensor([[-10], [10]])
np.linspace(pr[0].item(),pr[1].item(),10+1)
#pr[0].detach().numpy().item()

# %%
nf_mctm = NF_MCTM(polynomial_range=torch.tensor([[-10], [10]]), number_variables=3)

#nf_mctm.l1.params = nf_mctm.l1.params.double()

# %%
nf_mctm.l1.params
# Out:
# Parameter containing:
# tensor([[-10.0000, -10.0000, -10.0000],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931]], dtype=torch.float64,
#        requires_grad=True)

# %%
nf_mctm.l1.params
# Out:
# Parameter containing:
# tensor([[0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000]], requires_grad=True)

# %%
p = torch.FloatTensor(np.repeat(np.repeat(1/(10+1),10+1),3))
p = torch.reshape(p, (10 + 1, 3))

nf_mctm.l1.params = nn.Parameter(p)

# %%
nf_mctm.l1.params
# Out:
# Parameter containing:
# tensor([[0.0909, 0.0909, 0.0909],
#         [0.0909, 0.0909, 0.0909],
#         [0.0909, 0.0909, 0.0909],
#         [0.0909, 0.0909, 0.0909],
#         [0.0909, 0.0909, 0.0909],
#         [0.0909, 0.0909, 0.0909],
#         [0.0909, 0.0909, 0.0909],
#         [0.0909, 0.0909, 0.0909],
#         [0.0909, 0.0909, 0.0909],
#         [0.0909, 0.0909, 0.0909],
#         [0.0909, 0.0909, 0.0909]], requires_grad=True)

# %%
p = torch.FloatTensor(np.repeat(np.repeat(1/(10+1),10+1),3))

# %%
p = torch.reshape(p,(10+1, 3))

# %%
p.size()

# %%
p_res = p[:,0]
p_res[1:] = torch.matmul(torch.exp(p[1:,0]),torch.triu(torch.ones(10,10))) + p[1,0]

# %%
p_res

# %%
data = torch.reshape(torch.range(0, 1,1/100).repeat(3), (101, 3))
data.size()

# %%
from bernstein_transformation_layer import *

# %%
n =10
v = 0
a = p_res[v] * torch.FloatTensor([n]) * (b(torch.FloatTensor([v-1]), torch.FloatTensor([n-1]), data) -
                                         b(torch.FloatTensor([v]), torch.FloatTensor([n-1]), data))

# %%
data = torch.range(0, 1,1/100)

# %%
n = torch.tensor(6)
for v in range(6+1):
    v = torch.tensor(v)
    plt.plot(b(v, n, data))

# %%
data = torch.tensor(np.linspace(0,1,100))
params = torch.tensor(np.linspace(0,1,6+1))
pred = sum(params[v]*b(torch.tensor(v), n, data) for v in range(6+1))
plt.plot(pred,data)

# %%
par_restricted_opt = torch.tensor(np.linspace(0,1,6+1))

# %%
par_restricted_opt

# %%
torch.log(torch.diff(par_restricted_opt))

# %%
par_restricted_opt[0]

# %%
def compute_starting_values_berstein_polynomials(degree,min,max):
    par_restricted_opt = torch.tensor(np.linspace(min,max,degree+1))
    par_unristricted = par_restricted_opt
    par_unristricted[1:] = torch.log(torch.diff(par_restricted_opt))

    par_restricted_opt = torch.Tensor.repeat(par_unristricted,(3,1)).T
    #par_restricted_opt = torch.reshape(par_restricted_opt,(degree+1,3))

    return par_restricted_opt

example = compute_starting_values_berstein_polynomials(10,torch.tensor(-10),torch.tensor(10))

example.size()
# Out:
# torch.Size([11, 3])

# %%
nn.Parameter(example)
# Out:
# Parameter containing:
# tensor([[-10.0000, -10.0000, -10.0000],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931]], dtype=torch.float64,
#        requires_grad=True)

# %%
import numpy as np
np.linspace(2.0, 3.0, num=5)

# %%
np.exp(np.log(1))

# %%
polynomial_range = torch.tensor([[-10], [10]])

# %%
polynomial_range[1,0]
# Out:
# tensor(10)

# %%
compute_starting_values_berstein_polynomials(10,
                                             polynomial_range[0,0],
                                             polynomial_range[1,0])
# Out:
# tensor([[-10.0000, -10.0000, -10.0000],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931]], dtype=torch.float64)

# %%
nf_mctm = NF_MCTM(polynomial_range=torch.tensor([[-10], [10]]), number_variables=3)

nf_mctm.l1.params = nn.Parameter(compute_starting_values_berstein_polynomials(10,
                                             polynomial_range[0,0],
                                             polynomial_range[1,0]))

# %%
nf_mctm.l1.params
# Out:
# Parameter containing:
# tensor([[-10.0000, -10.0000, -10.0000],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931],
#         [  0.6931,   0.6931,   0.6931]], dtype=torch.float64,
#        requires_grad=True)

# %%
train(nf_mctm, y, iterations=200, verbose=False, patience=10, min_delta=0.0001)
# Out:
#   0%|                                                   | 0/200 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 train(nf_mctm, y, iterations=200, verbose=False, patience=10, min_delta=0.0001)
#
# File ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/training_helpers.py:85, in train(model, train_data, iterations, verbose, patience, min_delta)
#      83 def train(model, train_data, iterations=2000, verbose=True, patience=5, min_delta=1e-7):
# ---> 85     neg_log_likelihoods = optimize(train_data, model, objective, iterations = iterations, verbose=verbose, patience=patience, min_delta=min_delta) # Run training
#      87     # Plot neg_log_likelihoods over training iterations:
#      88     with sns.axes_style('ticks'):
#
# File ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/training_helpers.py:70, in optimize(y, model, objective, iterations, verbose, patience, min_delta)
#      68 neg_log_likelihoods = []
#      69 for _ in tqdm(range(iterations)):
# ---> 70     neg_log_likelihood = objective(y, model)
#      71     opt.step(closure)
#      72     neg_log_likelihoods.append(neg_log_likelihood.detach().numpy())
#
# File ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/training_helpers.py:11, in objective(y, model, avg)
#      10 def objective(y, model, avg = True):
# ---> 11     z, log_d = model(y, return_log_d = True)
#      12     log_likelihood_latent = Normal(0, 1).log_prob(z) # log p_source(z)
#      13     #print(log_likelihood_latent.size())
#      14     #print(log_d.size())
#      15     #print(log_d)
#
# File /opt/anaconda3/envs/probml_exercises/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[4], line 24, in NF_MCTM.forward(self, x, return_log_d)
#      22 def forward(self, x, return_log_d=False):
#      23     if return_log_d==True:
# ---> 24         output, log_d = self.l1(x, return_log_d = True)
#      25         output, log_d = self.l2(output, return_log_d = True)
#      26         #output = self.l3(output)
#      27         #output, log_d = self.l4(output, log_d, return_log_d = True)
#      28         #output = self.l5(output)
#      29         #output, log_d = self.l6(output, log_d, return_log_d=True)
#
# File /opt/anaconda3/envs/probml_exercises/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/bernstein_transformation_layer.py:86, in Transformation.forward(self, input, log_d, inverse, monotonically_increasing, return_log_d)
#      83 def forward(self, input, log_d = 0, inverse = False, monotonically_increasing = True, return_log_d = False):
#      84     # input dims: 0: observation number, 1: variable
#      85     if not inverse:
# ---> 86         output = multivariable_bernstein_prediction(input, self.degree, self.number_variables, self.params, self.polynomial_range, monotonically_increasing)
#      87         output_first_derivativ = multivariable_bernstein_prediction(input, self.degree, self.number_variables, self.params, self.polynomial_range, monotonically_increasing, derivativ=1)
#      88         log_d = log_d + torch.log(torch.abs(output_first_derivativ)) # Error this is false we require the derivativ of the bernstein polynomial!332'
#
# File ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/bernstein_transformation_layer.py:59, in multivariable_bernstein_prediction(input, degree, number_variables, params, polynomial_range, monotonically_increasing, derivativ)
#      57 output = input.clone()
#      58 for var_num in range(number_variables):
# ---> 59     output[:,var_num] = bernstein_prediction(params[:,var_num], input[:,var_num], degree, polynomial_range[:,var_num], monotonically_increasing, derivativ)
#      60 return output
#
# File ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/bernstein_transformation_layer.py:30, in bernstein_prediction(params_a, input_a, degree, polynomial_range, monotonically_increasing, derivativ)
#      28     params_restricted = params_a.clone()
#      29     #relu_obj = nn.ReLU()
# ---> 30     params_restricted[1:] = torch.matmul(torch.exp(params_a[1:]),torch.triu(torch.ones(degree,degree))) + params_a[1] #abs or exp
#      31     # cannot use exp as it destabilizes the optimisation using LBFGS, get inf for params fast?
#      32     # however with exp works really well and fast with adam
#      33     # Relu works for both, results are good except at lower end there is a cutoff somehow
#      34 else:
#      35     params_restricted = params_a.clone()
#
# RuntimeError: expected scalar type Double but found Float

# %%
z = nf_mctm.forward(y, return_log_d=False).detach().numpy()

# %%
sns.kdeplot(x=z[:,0], y=z[:,1])
plt.show()
sns.kdeplot(x=z[:,0], y=z[:,2])
plt.show()
sns.kdeplot(x=z[:,1], y=z[:,2])
plt.show()

# %%
fig = sm.qqplot(z[:,0], line='45')
plt.show()
fig = sm.qqplot(z[:,1], line='45')
plt.show()
fig = sm.qqplot(z[:,2], line='45')
plt.show()
