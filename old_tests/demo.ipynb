# %%
import torch
from torch import nn
import numpy as np
from torch.distributions import Normal, Laplace
import matplotlib.pyplot as plt
from torch import optim
from tqdm import tqdm
import seaborn as sns

# %%
from bernstein_transformation_layer import *
from training_helpers import *

# %%
y_distribution = Laplace(5, 3)
y = y_distribution.sample((2000,2)) # Generate training data
plt.hist(y[:,0].numpy(), bins=100)
plt.hist(y[:,1].numpy(), bins=100)
plt.show()

# %%
polynomial_range = torch.FloatTensor([[-40, -40],
                                          [40, 40]])
mctm = Transformation(degree=10, number_variables=2, polynomial_range=polynomial_range)

# %%
loss = train(mctm, y, iterations=120, verbose=False)
# Out:
#   7%|▋         | 8/120 [00:05<01:20,  1.39it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/cz/5x11gwq96ks_cqwqdky646540000gn/T/ipykernel_3141/3984384803.py in <module>
# ----> 1 loss = train(mctm, y, iterations=120, verbose=False)
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/training_helpers.py in train(model, train_data, iterations, verbose, patience, min_delta)
#      83 def train(model, train_data, iterations=2000, verbose=True, patience=5, min_delta=1e-7):
#      84
# ---> 85     neg_log_likelihoods = optimize(train_data, model, objective, iterations = iterations, verbose=verbose, patience=patience, min_delta=min_delta) # Run training
#      86
#      87     # Plot neg_log_likelihoods over training iterations:
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/training_helpers.py in optimize(y, model, objective, iterations, verbose, patience, min_delta)
#      69     for _ in tqdm(range(iterations)):
#      70         neg_log_likelihood = objective(y, model)
# ---> 71         opt.step(closure)
#      72         neg_log_likelihoods.append(neg_log_likelihood.detach().numpy())
#      73
#
# /opt/anaconda3/envs/mctm_pytorch_37/lib/python3.7/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /opt/anaconda3/envs/mctm_pytorch_37/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /opt/anaconda3/envs/mctm_pytorch_37/lib/python3.7/site-packages/torch/optim/lbfgs.py in step(self, closure)
#     435                     # no use to re-evaluate that function here
#     436                     with torch.enable_grad():
# --> 437                         loss = float(closure())
#     438                     flat_grad = self._gather_flat_grad()
#     439                     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# /opt/anaconda3/envs/mctm_pytorch_37/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/training_helpers.py in closure()
#      60     def closure():
#      61         opt.zero_grad()
# ---> 62         neg_log_likelihood = objective(y, model)# use the `objective` function
#      63         neg_log_likelihood.backward() # backpropagate the loss
#      64         return neg_log_likelihood
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/training_helpers.py in objective(y, model, avg)
#      10 def objective(y, model, avg = True):
#      11     z, log_d = model(y, return_log_d = True)
# ---> 12     log_likelihood_latent = Normal(0, 1).log_prob(z) # log p_source(z)
#      13     #print(log_likelihood_latent.size())
#      14     #print(log_d.size())
#
# /opt/anaconda3/envs/mctm_pytorch_37/lib/python3.7/site-packages/torch/distributions/normal.py in log_prob(self, value)
#      71     def log_prob(self, value):
#      72         if self._validate_args:
# ---> 73             self._validate_sample(value)
#      74         # compute the variance
#      75         var = (self.scale ** 2)
#
# /opt/anaconda3/envs/mctm_pytorch_37/lib/python3.7/site-packages/torch/distributions/distribution.py in _validate_sample(self, value)
#     287         if not valid.all():
#     288             raise ValueError(
# --> 289                 "Expected value argument "
#     290                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#     291                 f"to be within the support ({repr(support)}) "
#
# ValueError: Expected value argument (Tensor of shape (2000, 2)) to be within the support (Real()) of the distribution Normal(loc: 0.0, scale: 1.0), but found invalid values:
# tensor([[nan, nan],
#         [nan, nan],
#         [nan, nan],
#         ...,
#         [nan, nan],
#         [nan, nan],
#         [nan, nan]], grad_fn=<CopySlices>)

# %%
z, log_d = mctm.forward(y)
plt.hist(z[:,0].detach().numpy(), bins=100)
plt.hist(z[:,1].detach().numpy(), bins=100)
plt.show()

# %%
import statsmodels.api as sm

# %%
#create Q-Q plot with 45-degree line added to plot
fig = sm.qqplot(z[:,0].detach().numpy(), line='45')
plt.show()
fig = sm.qqplot(z[:,1].detach().numpy(), line='45')
plt.show()

# %%
polynomial_range = torch.FloatTensor([[-10, -10],
                                          [10, 10]])
mctm.approximate_inverse(y, polynomial_range_inverse= polynomial_range, iterations=5000)
# use cubic splines for approx?
# use linespace to have more observations to train on?
# how is it done in the tensorflow implementation
# Out:
#   3%|▎         | 135/5000 [00:06<03:49, 21.18it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/cz/5x11gwq96ks_cqwqdky646540000gn/T/ipykernel_65627/3004422234.py in <module>
#       1 polynomial_range = torch.FloatTensor([[-10, -10],
#       2                                           [10, 10]])
# ----> 3 mctm.approximate_inverse(y, polynomial_range_inverse= polynomial_range, iterations=5000)
#       4 # use cubic splines for approx?
#       5 # use linespace to have more observations to train on?
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/bernstein_transformation_layer.py in approximate_inverse(self, input, polynomial_range_inverse, iterations)
#      92             # needs to be computed manually at each step
#      93             input_space = input
# ---> 94             output_space = multivariable_bernstein_prediction(input_space, self.degree, self.number_variables, self.params, self.polynomial_range, monotonically_increasing=True)
#      95
#      96             opt_inv.zero_grad() # zero out gradients first on the optimizer
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/bernstein_transformation_layer.py in multivariable_bernstein_prediction(input, degree, number_variables, params, polynomial_range, monotonically_increasing, derivativ)
#      50     output = input.clone()
#      51     for var_num in range(number_variables):
# ---> 52         output[:,var_num] = bernstein_prediction(params[:,var_num], input[:,var_num], degree, polynomial_range[:,var_num], monotonically_increasing, derivativ)
#      53     return output
#      54
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/bernstein_transformation_layer.py in bernstein_prediction(params_a, input_a, degree, polynomial_range, monotonically_increasing, derivativ)
#      40
#      41     if derivativ == 0:
# ---> 42         return sum(params_restricted[v] * b(torch.FloatTensor([v]), torch.FloatTensor([n]), input_a) for v in range(n+1)) #before we had: params_restricted[v-1]
#      43     elif derivativ == 1:
#      44         return sum(params_restricted[v] * torch.FloatTensor([n]) * (b(torch.FloatTensor([v-1]), torch.FloatTensor([n-1]), input_a) -
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/bernstein_transformation_layer.py in <genexpr>(.0)
#      40
#      41     if derivativ == 0:
# ---> 42         return sum(params_restricted[v] * b(torch.FloatTensor([v]), torch.FloatTensor([n]), input_a) for v in range(n+1)) #before we had: params_restricted[v-1]
#      43     elif derivativ == 1:
#      44         return sum(params_restricted[v] * torch.FloatTensor([n]) * (b(torch.FloatTensor([v-1]), torch.FloatTensor([n-1]), input_a) -
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/bernstein_transformation_layer.py in b(v, n, x)
#      20 # https://docs.scipy.org/doc/scipy/reference/generated/scipy.interpolate.BPoly.html
#      21 def b(v, n, x):
# ---> 22     return torch_binom(n, v) * x**v * (1 - x)**(n - v)
#      23
#      24 def bernstein_prediction(params_a, input_a, degree, polynomial_range, monotonically_increasing=False, derivativ=0):
#
# /opt/anaconda3/envs/Statistical_Programming/lib/python3.9/site-packages/torch/_tensor.py in wrapped(*args, **kwargs)
#      37             if has_torch_function(args):
#      38                 return handle_torch_function(wrapped, args, *args, **kwargs)
# ---> 39             return f(*args, **kwargs)
#      40         except TypeError:
#      41             return NotImplemented
#
# KeyboardInterrupt:

# %%
evaluate(mctm)

# %%
def multivariable_lambda_prediction(input, degree, number_variables, params, polynomial_range, inverse=False, spline="bspline"):

    #steps
    output = input.clone()
    # loop over all variables
    params_index = 0

    for var_num in range(number_variables):
        #print(var_num)
        # loop over all before variables
        for covar_num in range(var_num):
            #print(covar_num)
            #print(params_index)

            # compute lambda fct value using before variable
            if inverse:
                #output into spline
                if spline == "bspline":
                    lambda_value = bspline_prediction(params[:, params_index], output[:,covar_num], degree, polynomial_range[:,covar_num], monotonically_increasing=False, derivativ=0)
                elif spline == "bernstein":
                    lambda_value = bernstein_prediction(params[:, params_index], output[:,covar_num], degree, polynomial_range[:,covar_num], monotonically_increasing=False, derivativ=0)
            else:
                #input into spline
                if spline == "bspline":
                    lambda_value = bspline_prediction(params[:, params_index], input[:,covar_num], degree, polynomial_range[:,covar_num], monotonically_increasing=False, derivativ=0)
                elif spline == "bernstein":
                    lambda_value = bernstein_prediction(params[:, params_index], input[:,covar_num], degree, polynomial_range[:,covar_num], monotonically_increasing=False, derivativ=0)

            # update
            # Cloning issue?
            if inverse:
                output[:,var_num] = output[:,var_num] - lambda_value * output[:,covar_num]
            else:
                output[:,var_num] = output[:,var_num] + lambda_value * input[:,covar_num]

            params_index += 1

    return output

class Decorrelation(nn.Module):
    def __init__(self, degree, number_variables, polynomial_range, spline="bspline"):
        super().__init__()
        self.degree  = degree
        self.number_variables = number_variables
        self.polynomial_range = polynomial_range
        self.num_lambdas = number_variables * (number_variables-1) / 2
        self.spline = spline
        # https://discuss.pytorch.org/t/how-to-turn-list-of-varying-length-tensor-into-a-tensor/1361
        # param dims: 0: basis, 1: variable
        p = torch.FloatTensor(np.repeat(np.repeat(0.1,self.degree+1), self.num_lambdas))

        if self.num_lambdas == 1:
            self.params = nn.Parameter(p.unsqueeze(1))
        else:
            self.params = nn.Parameter(torch.reshape(p,(self.degree+1, int(self.num_lambdas))))

    def forward(self, input, log_d = 0, inverse = False):
        if not inverse:
            output = multivariable_lambda_prediction(input, self.degree, self.number_variables, self.params, self.polynomial_range, inverse=False, spline=self.spline)
        else:
            output = multivariable_lambda_prediction(input, self.degree, self.number_variables, self.params, self.polynomial_range, inverse=True, spline=self.spline)
        return output, log_d

# %%
from decorrelation_layer import *

# %%
from torch.distributions.multivariate_normal import MultivariateNormal
loc = torch.zeros(3)
lam = torch.Tensor([[1, 0, 0],
                    [3, 1, 0],
                    [0, 0, 1]])
scale = lam @ torch.eye(3) @ torch.transpose(lam,0,1)
y_distribution = MultivariateNormal(loc, scale)
y = y_distribution.sample((2000,1)) # Generate training data
y = y.reshape((2000,3))
y.size()
# Out:
# torch.Size([2000, 3])

# %%
sns.kdeplot(x=y[:,0], y=y[:,1])
plt.show()
sns.kdeplot(x=y[:,0], y=y[:,2])
plt.show()
sns.kdeplot(x=y[:,1], y=y[:,2])
plt.show()

# %%
polynomial_range = torch.FloatTensor([[-15, -15, -15],
                                          [15, 15, 15]])
decorr = Decorrelation(degree=12, number_variables=3, polynomial_range=polynomial_range, spline="bspline")

# %%
train(decorr, y, iterations=200, verbose=False)
# Out:
#   0%|          | 1/200 [02:01<6:42:07, 121.25s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/cz/5x11gwq96ks_cqwqdky646540000gn/T/ipykernel_3141/1117001943.py in <module>
# ----> 1 train(decorr, y, iterations=200, verbose=False)
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/training_helpers.py in train(model, train_data, iterations, verbose, patience, min_delta)
#      83 def train(model, train_data, iterations=2000, verbose=True, patience=5, min_delta=1e-7):
#      84
# ---> 85     neg_log_likelihoods = optimize(train_data, model, objective, iterations = iterations, verbose=verbose, patience=patience, min_delta=min_delta) # Run training
#      86
#      87     # Plot neg_log_likelihoods over training iterations:
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/training_helpers.py in optimize(y, model, objective, iterations, verbose, patience, min_delta)
#      69     for _ in tqdm(range(iterations)):
#      70         neg_log_likelihood = objective(y, model)
# ---> 71         opt.step(closure)
#      72         neg_log_likelihoods.append(neg_log_likelihood.detach().numpy())
#      73
#
# /opt/anaconda3/envs/mctm_pytorch_37/lib/python3.7/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /opt/anaconda3/envs/mctm_pytorch_37/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /opt/anaconda3/envs/mctm_pytorch_37/lib/python3.7/site-packages/torch/optim/lbfgs.py in step(self, closure)
#     435                     # no use to re-evaluate that function here
#     436                     with torch.enable_grad():
# --> 437                         loss = float(closure())
#     438                     flat_grad = self._gather_flat_grad()
#     439                     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# /opt/anaconda3/envs/mctm_pytorch_37/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/training_helpers.py in closure()
#      60     def closure():
#      61         opt.zero_grad()
# ---> 62         neg_log_likelihood = objective(y, model)# use the `objective` function
#      63         neg_log_likelihood.backward() # backpropagate the loss
#      64         return neg_log_likelihood
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/training_helpers.py in objective(y, model, avg)
#       9
#      10 def objective(y, model, avg = True):
# ---> 11     z, log_d = model(y, return_log_d = True)
#      12     log_likelihood_latent = Normal(0, 1).log_prob(z) # log p_source(z)
#      13     #print(log_likelihood_latent.size())
#
# /opt/anaconda3/envs/mctm_pytorch_37/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/decorrelation_layer.py in forward(self, input, log_d, inverse, return_log_d)
#      69
#      70         if not inverse:
# ---> 71             output = multivariable_lambda_prediction(input, self.degree, self.number_variables, self.params, self.polynomial_range, inverse=False, spline=self.spline)
#      72         else:
#      73             output = multivariable_lambda_prediction(input, self.degree, self.number_variables, self.params, self.polynomial_range, inverse=True, spline=self.spline)
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/decorrelation_layer.py in multivariable_lambda_prediction(input, degree, number_variables, params, polynomial_range, inverse, spline)
#      34                 #input into spline
#      35                 if spline == "bspline":
# ---> 36                     lambda_value = bspline_prediction(params[:, params_index], input[:,covar_num], degree, polynomial_range[:,covar_num], monotonically_increasing=False, derivativ=0)
#      37                 elif spline == "bernstein":
#      38                     lambda_value = bernstein_prediction(params[:, params_index], input[:,covar_num], degree, polynomial_range[:,covar_num], monotonically_increasing=False, derivativ=0)
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/bspline_prediction.py in bspline_prediction(params_a, input_a, degree, polynomial_range, monotonically_increasing, derivativ)
#      69     #                           for (x, k) in zip(input_a, intervall_correspondance)])
#      70
# ---> 71     prediction = deBoor(x=input_a_clone, t=knots, c=params_restricted, p=2)
#      72
#      73     return prediction
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/bspline_prediction.py in deBoor(x, t, c, p)
#      34         k = torch.searchsorted(t, x[i]) - 1
#      35         k[k > (n - 1)] = 2 + 1
# ---> 36         k[k > (n - 1)] = 2 + (n - 1) - 1
#      37
#      38         d = [c[j + k - p] for j in range(0, p + 1)]
#
# KeyboardInterrupt:

# %%
decorr = Decorrelation(degree=10, number_variables=3, polynomial_range=polynomial_range, spline="bspline")

# %%
train(decorr, y, iterations=200, verbose=False)
# Out:
#  55%|█████▌    | 110/200 [00:43<00:35,  2.54it/s]
# Early Stop!

# %%
decorr.params
# Out:
# Parameter containing:
# tensor([[ 0.1000,  0.1000,  0.1000],
#         [ 0.1000,  0.1000,  1.2899],
#         [ 0.1000,  0.1000, -0.1314],
#         [-1.1455, -3.5968,  0.0571],
#         [-2.8777,  0.4060, -0.1192],
#         [-3.2153,  0.0594,  0.0698],
#         [-2.7429,  0.1996, -0.0935],
#         [-3.1027,  2.2726, -0.0110],
#         [ 0.1000,  0.1000, -0.3197],
#         [ 0.1000,  0.1000,  0.7458],
#         [ 0.1000,  0.1000,  0.1000]], requires_grad=True)

# %%
z, log_d = decorr.forward(y)
z = z.detach().numpy()
sns.kdeplot(x=z[:,0], y=z[:,1])
plt.show()
sns.kdeplot(x=z[:,0], y=z[:,2])
plt.show()
sns.kdeplot(x=z[:,1], y=z[:,2])
plt.show()

# %%
from torch.distributions.multivariate_normal import MultivariateNormal
loc = torch.zeros(2)
lam = torch.Tensor([[1, 0],
                    [1.5, 1]])
scale = lam @ torch.eye(2) @ torch.transpose(lam,0,1)
y_distribution = MultivariateNormal(loc, scale)
y = y_distribution.sample((2000,1)) # Generate training data
y = y.reshape((2000,2))
y.size()
# Out:
# torch.Size([2000, 2])

# %%
polynomial_range = torch.FloatTensor([[-10],[10]])
decorr = Decorrelation(degree=12, number_variables=2, polynomial_range=polynomial_range)

# %%
sns.kdeplot(x=y[:,0], y=y[:,1])
plt.show()

# %%
train(decorr, y, iterations=100, verbose=False)
# Out:
#  24%|██▍       | 24/100 [00:05<00:16,  4.62it/s]
# Early Stop!

# %%
z, log_d = decorr.forward(y)
z = z.detach().numpy()
sns.kdeplot(x=z[:,0], y=z[:,1])
plt.show()

# %%
z, log_d = decorr.forward(y)
y_hat, log_d = decorr.forward(z.detach(), inverse=True)
#require z.detach() in the backward pass for the bspline code

y_hat = y_hat.detach().numpy()
sns.kdeplot(x=y_hat[:,0], y=y_hat[:,1])
plt.show()

# %%
# Inverse works!
y_hat, log_d = decorr.forward(z.detach(), inverse=True)
y == y_hat
# why a false at the last position? even though the same
y[y.size(0)-1,:]
y_hat[y_hat.size(0)-1,:]
# Out:
# tensor([[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [ True,  True],
#         [ True, False]])

# %%
class Flip(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self,x):
        return torch.flip(x, [0])

# %%
class NF_MCTM(nn.Module):
    def __init__(self, polynomial_range, number_variables):
        super(NF_MCTM, self).__init__()
        self.polynomial_range = polynomial_range
        self.number_variables = number_variables

        self.model = nn.Sequential(
            Transformation(degree=10, number_variables=self.number_variables, polynomial_range=self.polynomial_range.repeat(1,3)),
            Decorrelation(degree=12, number_variables=self.number_variables, polynomial_range=self.polynomial_range.repeat(1,3), spline="bernstein"),
            Flip(),
            Decorrelation(degree=12, number_variables=self.number_variables, polynomial_range=self.polynomial_range.repeat(1,3), spline="bernstein"),
            Flip(),
            Decorrelation(degree=12, number_variables=self.number_variables, polynomial_range=self.polynomial_range.repeat(1,3), spline="bernstein"),
        )

    def forward(self, x):
        output = self.model(x)
        return output

# %%
nf_mctm = NF_MCTM(polynomial_range = torch.tensor([[-10],[10]]), number_variables=3)

# %%
torch.tensor([[-10],[10]]).repeat([1,3])
# Out:
# tensor([[-10, -10, -10],
#         [ 10,  10,  10]])

# %%
y.size()
# Out:
# torch.Size([2000, 3])

# %%
nf_mctm.forward(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cz/5x11gwq96ks_cqwqdky646540000gn/T/ipykernel_67385/386761123.py in <module>
# ----> 1 nf_mctm.forward(y)
#
# /var/folders/cz/5x11gwq96ks_cqwqdky646540000gn/T/ipykernel_67385/2686393585.py in forward(self, x)
#      15
#      16     def forward(self, x):
# ---> 17         output = self.model(x)
#      18         return output
#
# /opt/anaconda3/envs/Statistical_Programming/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/anaconda3/envs/Statistical_Programming/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     202     def forward(self, input):
#     203         for module in self:
# --> 204             input = module(input)
#     205         return input
#     206
#
# /opt/anaconda3/envs/Statistical_Programming/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/decorrelation_layer.py in forward(self, input, log_d, inverse)
#      68     def forward(self, input, log_d = 0, inverse = False):
#      69         if not inverse:
# ---> 70             output = multivariable_lambda_prediction(input, self.degree, self.number_variables, self.params, self.polynomial_range, inverse=False, spline=self.spline)
#      71         else:
#      72             output = multivariable_lambda_prediction(input, self.degree, self.number_variables, self.params, self.polynomial_range, inverse=True, spline=self.spline)
#
# ~/Desktop/Universitaet/Goettingen/5_Semester/master_thesis/mctm_pytorch/decorrelation_layer.py in multivariable_lambda_prediction(input, degree, number_variables, params, polynomial_range, inverse, spline)
#      13
#      14     #steps
# ---> 15     output = input.clone()
#      16     # loop over all variables
#      17     params_index = 0
#
# AttributeError: 'tuple' object has no attribute 'clone'

# %%
torch.flip(y, [0])
# Out:
# tensor([[-1.1932, -0.8018],
#         [ 0.8045,  0.8068],
#         [-2.0925, -2.6940],
#         ...,
#         [-1.5152, -2.0197],
#         [ 0.4196,  0.3493],
#         [-0.4228, -0.3820]])
